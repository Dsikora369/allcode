# %%
import torch
import numpy as np
from torchvision import datasets
import torchvision.transforms as transforms
import matplotlib.pyplot as plt
import torch.nn as nn
import torch.nn.functional as F
from torch import optim
from torch.utils.data.sampler import SubsetRandomSampler

# %%
num_workers = 0
batch_size = 20
valid_size = 0.2

transform = transforms.ToTensor()

train_data = datasets.MNIST(root = 'data', train = True, download = True, transform = transform)
test_data = datasets.MNIST(root = 'data', train = False, download = True, transform = transform)

num_train = len(train_data)
indices = list(range(num_train))
np.random.shuffle(indices)
split = int(np.floor(valid_size * num_train))
train_idx, valid_idx = indices[split:], indices[:split]
train_sampler = SubsetRandomSampler(train_idx)
valid_sampler = SubsetRandomSampler(valid_idx)

train_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, sampler = train_sampler, 
                                           num_workers = num_workers)
valid_loader = torch.utils.data.DataLoader(train_data, batch_size = batch_size, sampler = valid_sampler, 
                                           num_workers = num_workers)
test_loader = torch.utils.data.DataLoader(test_data, batch_size = batch_size, num_workers = num_workers)
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to data/MNIST/raw/train-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=9912422.0), HTML(value='')))
# Extracting data/MNIST/raw/train-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to data/MNIST/raw/train-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=28881.0), HTML(value='')))
# Extracting data/MNIST/raw/train-labels-idx1-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to data/MNIST/raw/t10k-images-idx3-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=1648877.0), HTML(value='')))
# Extracting data/MNIST/raw/t10k-images-idx3-ubyte.gz to data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 503: Service Unavailable
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# HBox(children=(FloatProgress(value=0.0, max=4542.0), HTML(value='')))
# Extracting data/MNIST/raw/t10k-labels-idx1-ubyte.gz to data/MNIST/raw
# /usr/local/lib/python3.7/dist-packages/torchvision/datasets/mnist.py:498: UserWarning: The given NumPy array is not writeable, and PyTorch does not support non-writeable tensors. This means you can write to the underlying (supposedly non-writeable) NumPy array using the tensor. You may want to copy the array to protect its data or make it writeable before converting it to a tensor. This type of warning will be suppressed for the rest of this program. (Triggered internally at  /pytorch/torch/csrc/utils/tensor_numpy.cpp:180.)
#   return torch.from_numpy(parsed.astype(m[2], copy=False)).view(*s)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(784, 512)
        self.fc2 = nn.Linear(512, 512)
        self.fc3 = nn.Linear(512, 10)
        self.dropout = nn.Dropout(0.5)
    
    def forward(self, x):
        x = x.view(x.shape[0], -1)
        x = self.dropout(F.relu(self.fc1(x)))
        x = self.dropout(F.relu(self.fc2(x)))
        x = self.fc3(x)
        return x

# %%
net = Net()
print(net)
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )

# %%
model = Net()
print(model)
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model.parameters(), lr = 0.003)
n_epochs = 70  # suggest training between 20-50 epochs
valid_loss_min = np.Inf
model.train() # prep model for training
streak = 0
for epoch in range(n_epochs):
    # monitor training loss
    train_loss = 0.0
    valid_loss = 0.0
    ###################
    # train the model #
    ###################
    for data, target in train_loader:
        # clear the gradients of all optimized variables
        optimizer.zero_grad()
        # forward pass: compute predicted outputs by passing inputs to the model
        output = model(data)
        # calculate the loss
        loss = criterion(output, target)
        # backward pass: compute gradient of the loss with respect to model parameters
        loss.backward()
        # perform a single optimization step (parameter update)
        optimizer.step()
        # update running training loss
        train_loss += loss.item()*data.size(0)
        
    # print training statistics 
    # calculate average loss over an epoch
    for data, target in valid_loader:
        output = model(data)
        
        loss = criterion(output, target)
        
        valid_loss +=loss.item()*data.size(0)
    train_loss = train_loss/len(train_loader.dataset)
    valid_loss = valid_loss/len(valid_loader.dataset)

    print('Epoch: {} \tTraining Loss: {:.6f} \tValidation Loss: {:.6f}'.format(
        epoch+1, 
        train_loss,
        valid_loss
        ))
    if valid_loss <= valid_loss_min:
        print('Validation loss decreased ({:.6f} --> {:.6f}). Saving model ...'.format(
            valid_loss_min,
            valid_loss))
        torch.save(model.state_dict(), 'model.pt')
        valid_loss_min = valid_loss
        streak = 0
    else:
        streak+=1
        if streak>4:
            break
model.load_state_dict(torch.load('model.pt')) 
test_loss = 0.0
class_correct = list(0. for i in range(10))
class_total = list(0. for i in range(10))

model.eval() # prep model for *evaluation*

for data, target in test_loader:
    # forward pass: compute predicted outputs by passing inputs to the model
    output = model(data)
    # calculate the loss
    loss = criterion(output, target)
    # update test loss 
    test_loss += loss.item()*data.size(0)
    # convert output probabilities to predicted class
    _, pred = torch.max(output, 1)
    # compare predictions to true label
    correct = np.squeeze(pred.eq(target.data.view_as(pred)))
    # calculate test accuracy for each object class
    for i in range(batch_size):
        label = target.data[i]
        class_correct[label] += correct[i].item()
        class_total[label] += 1

# calculate and print avg test loss
test_loss = test_loss/len(test_loader.dataset)
print('Test Loss: {:.6f}\n'.format(test_loss))
# Out:
# Net(
#   (fc1): Linear(in_features=784, out_features=512, bias=True)
#   (fc2): Linear(in_features=512, out_features=512, bias=True)
#   (fc3): Linear(in_features=512, out_features=10, bias=True)
#   (dropout): Dropout(p=0.5, inplace=False)
# )
# Epoch: 1 	Training Loss: 1.531913 	Validation Loss: 0.235204
# Validation loss decreased (inf --> 0.235204). Saving model ...
# Epoch: 2 	Training Loss: 0.657091 	Validation Loss: 0.131928
# Validation loss decreased (0.235204 --> 0.131928). Saving model ...
# Epoch: 3 	Training Loss: 0.449747 	Validation Loss: 0.105880
# Validation loss decreased (0.131928 --> 0.105880). Saving model ...
# Epoch: 4 	Training Loss: 0.376168 	Validation Loss: 0.093107
# Validation loss decreased (0.105880 --> 0.093107). Saving model ...
# Epoch: 5 	Training Loss: 0.338102 	Validation Loss: 0.084527
# Validation loss decreased (0.093107 --> 0.084527). Saving model ...
# Epoch: 6 	Training Loss: 0.308223 	Validation Loss: 0.078238
# Validation loss decreased (0.084527 --> 0.078238). Saving model ...
# Epoch: 7 	Training Loss: 0.284391 	Validation Loss: 0.073286
# Validation loss decreased (0.078238 --> 0.073286). Saving model ...
# Epoch: 8 	Training Loss: 0.264449 	Validation Loss: 0.068640
# Validation loss decreased (0.073286 --> 0.068640). Saving model ...
# Epoch: 9 	Training Loss: 0.248721 	Validation Loss: 0.065153
# Validation loss decreased (0.068640 --> 0.065153). Saving model ...
# Epoch: 10 	Training Loss: 0.234542 	Validation Loss: 0.063116
# Validation loss decreased (0.065153 --> 0.063116). Saving model ...
# Epoch: 11 	Training Loss: 0.220236 	Validation Loss: 0.059015
# Validation loss decreased (0.063116 --> 0.059015). Saving model ...
# Epoch: 12 	Training Loss: 0.209765 	Validation Loss: 0.055973
# Validation loss decreased (0.059015 --> 0.055973). Saving model ...
# Epoch: 13 	Training Loss: 0.200372 	Validation Loss: 0.054101
# Validation loss decreased (0.055973 --> 0.054101). Saving model ...
# Epoch: 14 	Training Loss: 0.189264 	Validation Loss: 0.052354
# Validation loss decreased (0.054101 --> 0.052354). Saving model ...
# Epoch: 15 	Training Loss: 0.180894 	Validation Loss: 0.049682
# Validation loss decreased (0.052354 --> 0.049682). Saving model ...
# Epoch: 16 	Training Loss: 0.173397 	Validation Loss: 0.048603
# Validation loss decreased (0.049682 --> 0.048603). Saving model ...
# Epoch: 17 	Training Loss: 0.167317 	Validation Loss: 0.046322
# Validation loss decreased (0.048603 --> 0.046322). Saving model ...
# Epoch: 18 	Training Loss: 0.160414 	Validation Loss: 0.045021
# Validation loss decreased (0.046322 --> 0.045021). Saving model ...
# Epoch: 19 	Training Loss: 0.153819 	Validation Loss: 0.043816
# Validation loss decreased (0.045021 --> 0.043816). Saving model ...
# Epoch: 20 	Training Loss: 0.149526 	Validation Loss: 0.042544
# Validation loss decreased (0.043816 --> 0.042544). Saving model ...
# Epoch: 21 	Training Loss: 0.143479 	Validation Loss: 0.041730
# Validation loss decreased (0.042544 --> 0.041730). Saving model ...
# Epoch: 22 	Training Loss: 0.140148 	Validation Loss: 0.040643
# Validation loss decreased (0.041730 --> 0.040643). Saving model ...
# Epoch: 23 	Training Loss: 0.135969 	Validation Loss: 0.040052
# Validation loss decreased (0.040643 --> 0.040052). Saving model ...
# Epoch: 24 	Training Loss: 0.132467 	Validation Loss: 0.040342
# Epoch: 25 	Training Loss: 0.129003 	Validation Loss: 0.037827
# Validation loss decreased (0.040052 --> 0.037827). Saving model ...
# Epoch: 26 	Training Loss: 0.125157 	Validation Loss: 0.036840
# Validation loss decreased (0.037827 --> 0.036840). Saving model ...
# Epoch: 27 	Training Loss: 0.122341 	Validation Loss: 0.036234
# Validation loss decreased (0.036840 --> 0.036234). Saving model ...
# Epoch: 28 	Training Loss: 0.118216 	Validation Loss: 0.034701
# Validation loss decreased (0.036234 --> 0.034701). Saving model ...
# Epoch: 29 	Training Loss: 0.115736 	Validation Loss: 0.034772
# Epoch: 30 	Training Loss: 0.112095 	Validation Loss: 0.033710
# Validation loss decreased (0.034701 --> 0.033710). Saving model ...
# Epoch: 31 	Training Loss: 0.109158 	Validation Loss: 0.034344
# Epoch: 32 	Training Loss: 0.107710 	Validation Loss: 0.032958
# Validation loss decreased (0.033710 --> 0.032958). Saving model ...
# Epoch: 33 	Training Loss: 0.104881 	Validation Loss: 0.032133
# Validation loss decreased (0.032958 --> 0.032133). Saving model ...
# Epoch: 34 	Training Loss: 0.103561 	Validation Loss: 0.031898
# Validation loss decreased (0.032133 --> 0.031898). Saving model ...
# Epoch: 35 	Training Loss: 0.099207 	Validation Loss: 0.031852
# Validation loss decreased (0.031898 --> 0.031852). Saving model ...
# Epoch: 36 	Training Loss: 0.097960 	Validation Loss: 0.031197
# Validation loss decreased (0.031852 --> 0.031197). Saving model ...
# Epoch: 37 	Training Loss: 0.095423 	Validation Loss: 0.030251
# Validation loss decreased (0.031197 --> 0.030251). Saving model ...
# Epoch: 38 	Training Loss: 0.094880 	Validation Loss: 0.030269
# Epoch: 39 	Training Loss: 0.093243 	Validation Loss: 0.029935
# Validation loss decreased (0.030251 --> 0.029935). Saving model ...
# Epoch: 40 	Training Loss: 0.090194 	Validation Loss: 0.029297
# Validation loss decreased (0.029935 --> 0.029297). Saving model ...
# Epoch: 41 	Training Loss: 0.089510 	Validation Loss: 0.029249
# Validation loss decreased (0.029297 --> 0.029249). Saving model ...
# Epoch: 42 	Training Loss: 0.086418 	Validation Loss: 0.029268
# Epoch: 43 	Training Loss: 0.085367 	Validation Loss: 0.029200
# Validation loss decreased (0.029249 --> 0.029200). Saving model ...
# Epoch: 44 	Training Loss: 0.082767 	Validation Loss: 0.028389
# Validation loss decreased (0.029200 --> 0.028389). Saving model ...
# Epoch: 45 	Training Loss: 0.082414 	Validation Loss: 0.028508
# Epoch: 46 	Training Loss: 0.081426 	Validation Loss: 0.026951
# Validation loss decreased (0.028389 --> 0.026951). Saving model ...
# Epoch: 47 	Training Loss: 0.079050 	Validation Loss: 0.027787
# Epoch: 48 	Training Loss: 0.078389 	Validation Loss: 0.026145
# Validation loss decreased (0.026951 --> 0.026145). Saving model ...
# Epoch: 49 	Training Loss: 0.076860 	Validation Loss: 0.027084
# Epoch: 50 	Training Loss: 0.074703 	Validation Loss: 0.027740
# Epoch: 51 	Training Loss: 0.073356 	Validation Loss: 0.027297
# Epoch: 52 	Training Loss: 0.072046 	Validation Loss: 0.026782
# Epoch: 53 	Training Loss: 0.071908 	Validation Loss: 0.025617
# Validation loss decreased (0.026145 --> 0.025617). Saving model ...
# Epoch: 54 	Training Loss: 0.071848 	Validation Loss: 0.025263
# Validation loss decreased (0.025617 --> 0.025263). Saving model ...
# Epoch: 55 	Training Loss: 0.069790 	Validation Loss: 0.025594
# Epoch: 56 	Training Loss: 0.070680 	Validation Loss: 0.025793
# Epoch: 57 	Training Loss: 0.069557 	Validation Loss: 0.024987
# Validation loss decreased (0.025263 --> 0.024987). Saving model ...
# Epoch: 58 	Training Loss: 0.067138 	Validation Loss: 0.025008
# Epoch: 59 	Training Loss: 0.066139 	Validation Loss: 0.024662
# Validation loss decreased (0.024987 --> 0.024662). Saving model ...
# Epoch: 60 	Training Loss: 0.066012 	Validation Loss: 0.025034
# Epoch: 61 	Training Loss: 0.063030 	Validation Loss: 0.025254
# Epoch: 62 	Training Loss: 0.063831 	Validation Loss: 0.025108
# Epoch: 63 	Training Loss: 0.062197 	Validation Loss: 0.023472
# Validation loss decreased (0.024662 --> 0.023472). Saving model ...
# Epoch: 64 	Training Loss: 0.060306 	Validation Loss: 0.024701
# Epoch: 65 	Training Loss: 0.060977 	Validation Loss: 0.023460
# Validation loss decreased (0.023472 --> 0.023460). Saving model ...
# Epoch: 66 	Training Loss: 0.058164 	Validation Loss: 0.023548
# Epoch: 67 	Training Loss: 0.057721 	Validation Loss: 0.023183
# Validation loss decreased (0.023460 --> 0.023183). Saving model ...
# Epoch: 68 	Training Loss: 0.057321 	Validation Loss: 0.023593
# Epoch: 69 	Training Loss: 0.055954 	Validation Loss: 0.023591
# Epoch: 70 	Training Loss: 0.055477 	Validation Loss: 0.023821
# Test Loss: 0.071666

# %%
print(sum(class_correct)/ 
      sum(class_total))
# Out:
# 0.9774
